# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
labels_ = [41,26,26,57,33,49,50,61,58,26,26,36,39,35,63,34,38,59,47,45,46,32,37,42,31,51,55,5,10,2,3,9,11,12,7,14,0,1,4,6,20,19,25,54,13,30,0,43,40,62,48,17,22,24,23,18,53,56,8,60,16,44,21,27,15,28,52,5,10,2,3,9,11,12,7,14,0,1,4,6,20,19,25,54,13,30,0,0,29]

# %%
df = pd.read_csv(Path(r"../data/blue_waters_posix_with_paths_no_negative_outliers_no_time_witherrors.csv"))

# %%
for cluster_id in range(0,64):
    print("Cluster " + str(cluster_id) + ": ")
    for cluster_mem_index in (i for i, e in enumerate(labels_) if e == cluster_id):
        print(df.columns[cluster_mem_index])
# Out:
# Cluster 0:
# POSIX_SIZE_READ_100M_1G
# POSIX_SIZE_WRITE_100M_1G
# READ_100M_1G
# WRITE_100M_1G
# WRITE_1G_PLUS
# Cluster 1:
# POSIX_SIZE_READ_1G_PLUS
# READ_1G_PLUS
# Cluster 2:
# POSIX_SIZE_READ_100_1K
# READ_100_1K
# Cluster 3:
# POSIX_SIZE_READ_1K_10K
# READ_1K_10K
# Cluster 4:
# POSIX_SIZE_WRITE_0_100
# WRITE_0_100
# Cluster 5:
# POSIX_MAX_WRITE_TIME_SIZE
# POSIX_SLOWEST_RANK_BYTES
# Cluster 6:
# POSIX_SIZE_WRITE_100_1K
# WRITE_100_1K
# Cluster 7:
# POSIX_SIZE_READ_4M_10M
# READ_4M_10M
# Cluster 8:
# POSIX_ACCESS3_ACCESS
# Cluster 9:
# POSIX_SIZE_READ_10K_100K
# READ_10K_100K
# Cluster 10:
# POSIX_SIZE_READ_0_100
# READ_0_100
# Cluster 11:
# POSIX_SIZE_READ_100K_1M
# READ_100K_1M
# Cluster 12:
# POSIX_SIZE_READ_1M_4M
# READ_1M_4M
# Cluster 13:
# POSIX_SIZE_WRITE_4M_10M
# WRITE_4M_10M
# Cluster 14:
# POSIX_SIZE_READ_10M_100M
# READ_10M_100M
# Cluster 15:
# POSIX_FASTEST_RANK
# Cluster 16:
# POSIX_ACCESS1_COUNT
# Cluster 17:
# POSIX_STRIDE4_STRIDE
# Cluster 18:
# ...
