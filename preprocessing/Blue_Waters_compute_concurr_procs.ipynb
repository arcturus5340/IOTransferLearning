# %%
import pandas as pd
from pathlib import Path

# %%
df_blue_waters_posix = pd.read_csv(Path(r"../data/blue_waters_posix_with_paths_no_negative_outliers.csv"))
df_blue_waters_posix.head()
# Out:
#    POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 0         1280          -1281       -1281         1807             0
# 1       168420          -5232       -5232      7505724       5401751
# 2        62567          -1477       -1477      2300215        441912
# 3         2366          -2367       -2367         3342             0
# 4         8709           -288        -288      1521073       6331589
#
#    POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  POSIX_RENAME_SOURCES  \
# 0            0         2561            0             0                 -1281
# 1     11345341       394840            0             1                 -5232
# 2      1214829       280660            0             1                 -1477
# 3            0         4733            0             0                 -2367
# 4      2013343        28430            0             0                  -288
#
#    ...  POSIX_F_MAX_WRITE_TIME  POSIX_F_FASTEST_RANK_TIME  \
# 0  ...                0.000000                        0.0
# 1  ...                0.379682                        0.0
# 2  ...                0.343959                        0.0
# 3  ...                0.000000                        0.0
# 4  ...                0.303372                        0.0
#
#    POSIX_F_SLOWEST_RANK_TIME  start_time_sec  end_time_sec  nprocs  \
# 0                   0.000000      1540486184    1540486762     213
# 1                   1.294190      1540414582    1540499232      80
# 2                   0.571395      1540480731    1540488696      48
# 3                   0.000000      1540498498    1540499201     394
# 4                  56.737093      1540442491    1540443028     256
#
#                            exe  lustre    bandwidth  \
# 0                       Hsigma       1     0.883451
# 1                         SpEC       1   126.224526
# 2                         SpEC       1  2621.222063
# 3                       Hsigma       1     3.233117
# 4  CCTM_v52_Linux2_x86_64intel       1   364.725531
#
#                                                 path
# 0  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 2  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 3  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4  /hpcwork/noco0056/io_transfer_learning/data/bl...
#
# [5 rows x 103 columns]

# %%
def compute_concurr_procs(x):
    starts_same_time = (df_blue_waters_posix.start_time_sec >= x.start_time_sec) & (df_blue_waters_posix.start_time_sec <= x.end_time_sec)
    ends_same_time = (df_blue_waters_posix.end_time_sec >= x.start_time_sec) & (df_blue_waters_posix.end_time_sec <= x.end_time_sec)
    return len(df_blue_waters_posix[starts_same_time | ends_same_time])

# %%
df_blue_waters_posix["concurr_procs"] = df_blue_waters_posix.apply(lambda x: compute_concurr_procs(x), axis=1)
df_blue_waters_posix.head()
# Out:
#    POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 0         1280          -1281       -1281         1807             0
# 1       168420          -5232       -5232      7505724       5401751
# 2        62567          -1477       -1477      2300215        441912
# 3         2366          -2367       -2367         3342             0
# 4         8709           -288        -288      1521073       6331589
#
#    POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  POSIX_RENAME_SOURCES  \
# 0            0         2561            0             0                 -1281
# 1     11345341       394840            0             1                 -5232
# 2      1214829       280660            0             1                 -1477
# 3            0         4733            0             0                 -2367
# 4      2013343        28430            0             0                  -288
#
#    ...  POSIX_F_FASTEST_RANK_TIME  POSIX_F_SLOWEST_RANK_TIME  start_time_sec  \
# 0  ...                        0.0                   0.000000      1540486184
# 1  ...                        0.0                   1.294190      1540414582
# 2  ...                        0.0                   0.571395      1540480731
# 3  ...                        0.0                   0.000000      1540498498
# 4  ...                        0.0                  56.737093      1540442491
#
#    end_time_sec  nprocs                          exe  lustre    bandwidth  \
# 0    1540486762     213                       Hsigma       1     0.883451
# 1    1540499232      80                         SpEC       1   126.224526
# 2    1540488696      48                         SpEC       1  2621.222063
# 3    1540499201     394                       Hsigma       1     3.233117
# 4    1540443028     256  CCTM_v52_Linux2_x86_64intel       1   364.725531
#
#                                                 path  concurr_procs
# 0  /hpcwork/noco0056/io_transfer_learning/data/bl...             36
# 1  /hpcwork/noco0056/io_transfer_learning/data/bl...            846
# 2  /hpcwork/noco0056/io_transfer_learning/data/bl...             91
# 3  /hpcwork/noco0056/io_transfer_learning/data/bl...             55
# 4  /hpcwork/noco0056/io_transfer_learning/data/bl...              7
#
# [5 rows x 104 columns]

# %%
df_blue_waters_posix.to_csv(Path(r"../data/blue_waters_posix_with_paths_no_negative_outliers_concurr_procs.csv"),index=False)
