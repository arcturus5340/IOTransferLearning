# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/blue_waters_posix_all_no_outliers.csv")

# %%
df = df[df["nprocs"].isin([4, 16, 48, 64, 144, 240])]
df
# Out:
#         POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 56            39775          -1324       -1324      3348398       2023225
# 359           73579           -699        -699      2632037         41984
# 363           41229          -1263       -1263      5029637       3252692
# 366           31050           -895        -895       931038        132468
# 367            4800           -758        -758       211710        133292
# ...             ...            ...         ...          ...           ...
# 723937         1875           -782        -782       463075          7675
# 723965         4830           -750        -750       221766        137222
# 723971        19501          -1414       -1414      4024075       3041091
# 723980         1875           -782        -782       463075          7675
# 724021         4838           -768        -768       218802        134736
#
#         POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# ...

# %%
df["nprocs"].value_counts().sort_index()
# Out:
# nprocs
# 4        3433
# 16     104793
# 48     199218
# 64      38274
# 144      4040
# 240        62
# Name: count, dtype: int64

# %%
df.to_csv("../data/blue_waters_posix_no_outliers_4_16_48_64_144_240_nprocs.csv", index=False)
