# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/blue_waters_posix_no_outliers.csv")

# %%
df = df[df["nprocs"].isin([4, 16, 48, 64, 144, 240])]
df
# Out:
#         POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 8              4870           -792        -792       216275        135216
# 9             47864           -912        -912      1632215        145357
# 10             6918           -897        -897      3414728       2916487
# 15             6751           -874        -874      1081394        853013
# 16            77666           -748        -748      2943105        296788
# ...             ...            ...         ...          ...           ...
# 724024        25004          -1288       -1288      3908646       3326772
# 724025         4870           -800        -800       216509        133294
# 724026        27899           -706        -706       824117        136902
# 724027        12571          -1000       -1000       781645        355445
# 724029         9927           -890        -890      3640566       3018272
#
#         POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# 8            205111        15951            0             1
# 9           1064440       129731            0             1
# 10          5434114       109523            0             1
# 15          1493947        61126            0             1
# 16          1873612       224671            0             1
# ...             ...          ...          ...           ...
# 724024      5245647       468926            0             1
# 724025       204742        15981            0             1
# 724026       632480        70722            0             1
# 724027       653876        80989            0             1
# 724029      5706358       176916            0             1
#
#         POSIX_RENAME_SOURCES  ...  POSIX_F_FASTEST_RANK_TIME  \
# 8                       -792  ...                        0.0
# 9                       -912  ...                        0.0
# 10                      -897  ...                        0.0
# 15                      -874  ...                        0.0
# 16                      -748  ...                        0.0
# ...                      ...  ...                        ...
# 724024                 -1288  ...                        0.0
# 724025                  -800  ...                        0.0
# 724026                  -706  ...                        0.0
# 724027                 -1000  ...                        0.0
# 724029                  -890  ...                        0.0
#
#         POSIX_F_SLOWEST_RANK_TIME  start_time_sec  end_time_sec  nprocs  \
# 8                        0.735744      1540420499    1540421012      48
# 9                        2.666620      1540485088    1540487684      48
# 10                       0.429495      1540414373    1540498945      48
# 15                       0.598302      1540420003    1540442686      48
# 16                       1.916454      1540447353    1540453286      48
# ...                           ...             ...           ...     ...
# 724024                   0.974784      1506621629    1506693654      48
# 724025                   0.720533      1506609532    1506610004      48
# 724026                   0.914386      1506629880    1506630161      48
# 724027                   0.752825      1506647712    1506651237      48
# 724029                   0.715079      1506612023    1506695745      48
#
#         run_time  log_ver   exe  lustre   bandwidth
# 8          514.0      3.1  SpEC       1   46.554144
# 9         2597.0      3.1  SpEC       1  352.539247
# 10       84573.0      3.1  SpEC       1  115.303713
# 15       22684.0      3.1  SpEC       1  232.904128
# 16        5934.0      3.1  SpEC       1  587.173510
# ...          ...      ...   ...     ...         ...
# 724024   72026.0      3.1  SpEC       1  117.217110
# 724025     473.0      3.1  SpEC       1   37.922704
# 724026     282.0      3.1  SpEC       1  164.318747
# 724027    3526.0      3.1  SpEC       1  236.018095
# 724029   83723.0      3.1  SpEC       1  141.832395
#
# [349820 rows x 104 columns]

# %%
df["nprocs"].value_counts().sort_index()
# Out:
# nprocs
# 4        3433
# 16     104793
# 48     199218
# 64      38274
# 144      4040
# 240        62
# Name: count, dtype: int64

# %%
df.to_csv("../data/blue_waters_posix_no_outliers_4_16_48_64_144_240_nprocs.csv", index=False)
