# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# ## Finding duplicate rows

# %% [markdown]
# Load dataset without timing features, otherwise there will be no duplicates.

# %%
df_no_time = pd.read_csv(Path(r"../data/blue_waters_posix_with_paths_no_negative_outliers_no_time.csv"))

# %% [markdown]
# ### Try with vasp_gam as test app

# %%
test_app = df_no_time[df_no_time.exe.str.strip() == 'vasp_gam']
test_app.head()
# Out:
#       POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 4050        16646            -17         -17       253920        264620
# 4056        16344            -17         -17       253920        271720
# 4060        13706            -17         -17       312320         32569
# 4062        13266            -17         -17       308480         22241
# 4067        13260            -17         -17       308480         19644
#
#       POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# 4050       218648        16646            0             0
# 4056       218044        16344            0             0
# 4060       255106        13706            0             0
# 4062       251299        13266            0             0
# 4067       251095        13260            0             0
#
#       POSIX_RENAME_SOURCES  ...  WRITE_4M_10M  WRITE_10M_100M  WRITE_100M_1G  \
# 4050                   -17  ...             0               0              0
# 4056                   -17  ...             0               0              0
# 4060                   -17  ...             0               0              0
# 4062                   -17  ...             0               0              0
# 4067                   -17  ...             0               0              0
#
#       WRITE_1G_PLUS  rank  POSIX_TOTAL_TIME  nprocs        exe  lustre  \
# 4050              0    -1         90.587130      96  vasp_gam        1
# 4056              0    -1         96.198886      96  vasp_gam        1
# 4060              0    -1         42.093948     256  vasp_gam        1
# 4062              0    -1         38.330144     256  vasp_gam        1
# 4067              0    -1         28.921739     256  vasp_gam        1
#
#                                                    path
# 4050  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4056  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4060  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4062  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4067  /hpcwork/noco0056/io_transfer_learning/data/bl...
#
# [5 rows x 93 columns]

# %%
test_app_dups = test_app[test_app.POSIX_BYTES_READ.duplicated() & test_app.POSIX_BYTES_WRITTEN.duplicated()]
len(test_app_dups)
# Out:
# 45840

# %%
test_app_no_dups = test_app[(test_app.POSIX_BYTES_READ.duplicated() == False) & (test_app.POSIX_BYTES_WRITTEN.duplicated() == False)]
test_app_no_dups.head()
# Out:
#       POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 4050        16646            -17         -17       253920        264620
# 4056        16344            -17         -17       253920        271720
# 4060        13706            -17         -17       312320         32569
# 4062        13266            -17         -17       308480         22241
# 4067        13260            -17         -17       308480         19644
#
#       POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# 4050       218648        16646            0             0
# 4056       218044        16344            0             0
# 4060       255106        13706            0             0
# 4062       251299        13266            0             0
# 4067       251095        13260            0             0
#
#       POSIX_RENAME_SOURCES  ...  WRITE_4M_10M  WRITE_10M_100M  WRITE_100M_1G  \
# 4050                   -17  ...             0               0              0
# 4056                   -17  ...             0               0              0
# 4060                   -17  ...             0               0              0
# 4062                   -17  ...             0               0              0
# 4067                   -17  ...             0               0              0
#
#       WRITE_1G_PLUS  rank  POSIX_TOTAL_TIME  nprocs        exe  lustre  \
# 4050              0    -1         90.587130      96  vasp_gam        1
# 4056              0    -1         96.198886      96  vasp_gam        1
# 4060              0    -1         42.093948     256  vasp_gam        1
# 4062              0    -1         38.330144     256  vasp_gam        1
# 4067              0    -1         28.921739     256  vasp_gam        1
#
#                                                    path
# 4050  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4056  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4060  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4062  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4067  /hpcwork/noco0056/io_transfer_learning/data/bl...
#
# [5 rows x 93 columns]

# %%
test_dup_set = test_app[(test_app.POSIX_BYTES_READ == test_app_no_dups.iloc[2].POSIX_BYTES_READ)
         & (test_app.POSIX_BYTES_WRITTEN == test_app_no_dups.iloc[2].POSIX_BYTES_WRITTEN)]
test_dup_set
# Out:
#       POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 4060        13706            -17         -17       312320         32569
#
#       POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# 4060       255106        13706            0             0
#
#       POSIX_RENAME_SOURCES  ...  WRITE_4M_10M  WRITE_10M_100M  WRITE_100M_1G  \
# 4060                   -17  ...             0               0              0
#
#       WRITE_1G_PLUS  rank  POSIX_TOTAL_TIME  nprocs        exe  lustre  \
# 4060              0    -1         42.093948     256  vasp_gam        1
#
#                                                    path
# 4060  /hpcwork/noco0056/io_transfer_learning/data/bl...
#
# [1 rows x 93 columns]

# %% [markdown]
# Specify columns that may differ such that the corresponding rows are still considered as duplicate jobs:
# - POSIX_MAX_(READ/WRITE)\_Time_Size: which operation is the slowest/fastest might be affected by concurrent jobs running at the same time, possibly on the same node as well as IO weather.
# - POSIX_(FASTEST/SLOWEST)\_RANK: same as above.
# - POSIX_TOTAL_TIME: is the output feature
# - rank: duplicate jobs may have been scheduled to different nodes.

# %%
columns_dissimilar = ["POSIX_MAX_READ_TIME_SIZE", "POSIX_MAX_WRITE_TIME_SIZE", "POSIX_FASTEST_RANK", "POSIX_SLOWEST_RANK",
                      "rank","POSIX_TOTAL_TIME"]

# %%
test_app[test_app.duplicated(test_app.columns.difference(columns_dissimilar))]
# Out:
#         POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 4441           2314            -13         -13         4608            16
# 4455           3578            -17         -17        77120         26022
# 4518           3182            -20         -20        75713      58079393
# 4598           3182            -20         -20        75713      59738273
# 4649           3182            -20         -20        75713      58079393
# ...             ...            ...         ...          ...           ...
# 777677          882            -20         -20       147408      34572112
# 777680          822            -20         -20        91970      29500157
# 777681          818            -20         -20        94089      20325966
# 810837         3150            -20         -20        67648      12445960
# 810897         3150            -20         -20        67648      12445960
#
#         POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# 4441            194         2314            0             0
# 4455          64139         3578            0             0
# 4518          61515         3246            0             0
# 4598          61515         3246            0             0
# 4649          61515         3246            0             0
# ...             ...          ...          ...           ...
# 777677        16006          898            0             0
# 777680        15637          838            0             0
# 777681        15318          834            0             0
# 810837        60106         3214            0             0
# 810897        60106         3214            0             0
#
#         POSIX_RENAME_SOURCES  ...  WRITE_4M_10M  WRITE_10M_100M  \
# 4441                     -13  ...             0               0
# 4455                     -17  ...             0               0
# 4518                     -20  ...             0               0
# 4598                     -20  ...             0               0
# 4649                     -20  ...             0               0
# ...                      ...  ...           ...             ...
# 777677                   -20  ...             0               0
# 777680                   -20  ...             0               0
# 777681                   -20  ...             0               0
# 810837                   -20  ...             0               0
# 810897                   -20  ...             0               0
#
#         WRITE_100M_1G  WRITE_1G_PLUS  rank  POSIX_TOTAL_TIME  nprocs  \
# 4441                0              0    -1          2.733955     192
# 4455                0              0    -1         12.016318      64
# 4518                0              0    -1        296.457484      64
# 4598                0              0    -1        313.086068      64
# 4649                0              0    -1        298.274991      64
# ...               ...            ...   ...               ...     ...
# 777677              0              0    -1        256.205289      16
# 777680              0              0    -1        150.464894      16
# 777681              0              0    -1        158.052334      16
# 810837              0              0    -1         63.009715      64
# 810897              0              0    -1         63.310301      64
#
#               exe  lustre                                               path
# 4441    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4455    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4518    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4598    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4649    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# ...           ...     ...                                                ...
# 777677  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 777680  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 777681  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 810837  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 810897  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
#
# [41284 rows x 93 columns]

# %% [markdown]
# ### Now find duplicates for the entire dataset

# %%
df_no_time_dups = df_no_time[df_no_time.duplicated(df_no_time.columns.difference(columns_dissimilar))]
df_no_time_dups.head()
# Out:
#      POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 106         2540          -2541       -2541         3499             0
# 143         1027          -1024       -1024           33            20
# 159         1922          -1923       -1923         2713             0
# 203         2234          -2235       -2235         3134             0
# 204         2522          -2523       -2523         3491             0
#
#      POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# 106            0         5081            0             0
# 143           14            3            0             0
# 159            0         3845            0             0
# 203            0         4469            0             0
# 204            0         5045            0             0
#
#      POSIX_RENAME_SOURCES  ...  WRITE_4M_10M  WRITE_10M_100M  WRITE_100M_1G  \
# 106                 -2541  ...             0               0              0
# 143                 -1024  ...             0               0              0
# 159                 -1923  ...             0               0              0
# 203                 -2235  ...             0               0              0
# 204                 -2523  ...             0               0              0
#
#      WRITE_1G_PLUS  rank  POSIX_TOTAL_TIME  nprocs         exe  lustre  \
# 106              0     7          2.461696     423   ./Hsigma        1
# 143              0     0          0.085740     768  ./nek5000        1
# 159              0   289          1.563848     320   ./Hsigma        1
# 203              0    76          1.116228     372   ./Hsigma        1
# 204              0   415          2.611028     420   ./Hsigma        1
#
#                                                   path
# 106  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 143  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 159  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 203  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 204  /hpcwork/noco0056/io_transfer_learning/data/bl...
#
# [5 rows x 93 columns]

# %%
df_no_time_no_dups = df_no_time[df_no_time.duplicated(df_no_time.columns.difference(columns_dissimilar)) == False]

# %%
df_no_time_no_dups.to_csv(r"../data/blue_waters_posix_with_paths_no_negative_outliers_no_time_no_dups.csv",index=False)
