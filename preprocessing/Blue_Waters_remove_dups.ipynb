# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# ## Finding duplicate rows

# %% [markdown]
# Load dataset without timing features, otherwise there will be no duplicates.

# %%
df_no_time = pd.read_csv(Path(r"../data/blue_waters_posix_with_paths_no_negative_outliers_no_time.csv"))

# %% [markdown]
# ### Try with vasp_gam as test app

# %%
test_app = df_no_time[df_no_time.exe.str.strip() == 'vasp_gam']
test_app.head(20)
# Out:
#       POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 4050        16646            -17         -17       253920        264620
# 4056        16344            -17         -17       253920        271720
# 4060        13706            -17         -17       312320         32569
# 4062        13266            -17         -17       308480         22241
# 4067        13260            -17         -17       308480         19644
# 4092         4158            -17         -17        80960         48103
# 4097        13998            -17         -17       316160         36310
# 4098         3742            -17         -17        79040         31874
# 4116         3572            -17         -17        78080         25963
# 4118         3752            -17         -17        79040         32036
# 4131        13276            -17         -17       308480         20219
# 4132        13274            -17         -17       308480         20088
# 4146         3660            -17         -17        78080         28288
# 4153        13628            -17         -17       312320         28442
# 4155        13304            -17         -17       308480         25138
# 4157        13406            -17         -17       308480         28562
# 4160        13324            -17         -17       308480         24510
# 4167         4226            -17         -17        80960         49472
# 4168        12982            -17         -17       304640         16938
# 4169        13952            -17         -17       316160         29207
#
#       POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# 4050       218648        16646            0             0
# 4056       218044        16344            0             0
# 4060       255106        13706            0             0
# 4062       251299        13266            0             0
# 4067       251095        13260            0             0
# 4092        68199         4158            0             0
# 4097       258505        13998            0             0
# 4098        65873         3742            0             0
# 4116        64818         3572            0             0
# 4118        65881         3752            0             0
# 4131       251127        13276            0             0
# 4132       251123        13274            0             0
# 4146        64970         3660            0             0
# 4153       254870        13628            0             0
# 4155       251471        13304            0             0
# 4157       251691        13406            0             0
# 4160       251447        13324            0             0
# 4167        68311         4226            0             0
# 4168       247724        12982            0             0
# 4169       258109        13952            0             0
#
#       POSIX_RENAME_SOURCES  ...  WRITE_4M_10M  WRITE_10M_100M  WRITE_100M_1G  \
# 4050                   -17  ...             0               0              0
# 4056                   -17  ...             0               0              0
# 4060                   -17  ...             0               0              0
# 4062                   -17  ...             0               0              0
# 4067                   -17  ...             0               0              0
# 4092                   -17  ...             0               0              0
# 4097                   -17  ...             0               0              0
# 4098                   -17  ...             0               0              0
# 4116                   -17  ...             0               0              0
# 4118                   -17  ...             0               0              0
# 4131                   -17  ...             0               0              0
# 4132                   -17  ...             0               0              0
# 4146                   -17  ...             0               0              0
# 4153                   -17  ...             0               0              0
# 4155                   -17  ...             0               0              0
# 4157                   -17  ...             0               0              0
# 4160                   -17  ...             0               0              0
# 4167                   -17  ...             0               0              0
# 4168                   -17  ...             0               0              0
# 4169                   -17  ...             0               0              0
#
#       WRITE_1G_PLUS  rank  POSIX_TOTAL_TIME  nprocs        exe  lustre  \
# 4050              0    -1         90.587130      96  vasp_gam        1
# 4056              0    -1         96.198886      96  vasp_gam        1
# 4060              0    -1         42.093948     256  vasp_gam        1
# 4062              0    -1         38.330144     256  vasp_gam        1
# 4067              0    -1         28.921739     256  vasp_gam        1
# 4092              0    -1         14.846425      64  vasp_gam        1
# 4097              0    -1         33.467017     256  vasp_gam        1
# 4098              0    -1         14.809738      64  vasp_gam        1
# 4116              0    -1         11.684875      64  vasp_gam        1
# 4118              0    -1         12.393222      64  vasp_gam        1
# 4131              0     0         44.070331     256  vasp_gam        1
# 4132              0    -1         25.005781     256  vasp_gam        1
# 4146              0    -1         10.992077      64  vasp_gam        1
# 4153              0    -1         37.461089     256  vasp_gam        1
# 4155              0    -1         29.863534     256  vasp_gam        1
# 4157              0    -1         36.002161     256  vasp_gam        1
# 4160              0    -1         36.022351     256  vasp_gam        1
# 4167              0    -1         14.275656      64  vasp_gam        1
# 4168              0    -1         25.173729     256  vasp_gam        1
# 4169              0    -1         28.146994     256  vasp_gam        1
#
#                                                    path
# 4050  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4056  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4060  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4062  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4067  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4092  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4097  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4098  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4116  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4118  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4131  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4132  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4146  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4153  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4155  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4157  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4160  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4167  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4168  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4169  /hpcwork/noco0056/io_transfer_learning/data/bl...
#
# [20 rows x 93 columns]

# %%
test_app_dups = test_app[test_app.POSIX_BYTES_READ.duplicated() & test_app.POSIX_BYTES_WRITTEN.duplicated()]
len(test_app_dups)
# Out:
# 45840

# %%
test_app_no_dups = test_app[(test_app.POSIX_BYTES_READ.duplicated() == False) & (test_app.POSIX_BYTES_WRITTEN.duplicated() == False)]
test_app_no_dups
# Out:
#         POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 4050          16646            -17         -17       253920        264620
# 4056          16344            -17         -17       253920        271720
# 4060          13706            -17         -17       312320         32569
# 4062          13266            -17         -17       308480         22241
# 4067          13260            -17         -17       308480         19644
# ...             ...            ...         ...          ...           ...
# 777396          864            -20         -20        91287      29272021
# 777433          306            -20         -20       128257      33189482
# 777507          272            -20         -20        81606      30975348
# 777553          248            -20         -20        99469      38228657
# 777625          246            -20         -20        77965      29499728
#
#         POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# 4050         218648        16646            0             0
# 4056         218044        16344            0             0
# 4060         255106        13706            0             0
# 4062         251299        13266            0             0
# 4067         251095        13260            0             0
# ...             ...          ...          ...           ...
# 777396        15607          880            0             0
# 777433         4664          310            0             0
# 777507         4373          276            0             0
# 777553         4277          252            0             0
# 777625         4321          250            0             0
#
#         POSIX_RENAME_SOURCES  ...  WRITE_4M_10M  WRITE_10M_100M  \
# 4050                     -17  ...             0               0
# 4056                     -17  ...             0               0
# 4060                     -17  ...             0               0
# 4062                     -17  ...             0               0
# 4067                     -17  ...             0               0
# ...                      ...  ...           ...             ...
# 777396                   -20  ...             0               0
# 777433                   -20  ...             0               0
# 777507                   -20  ...             0               0
# 777553                   -20  ...             0               0
# 777625                   -20  ...             0               0
#
#         WRITE_100M_1G  WRITE_1G_PLUS  rank  POSIX_TOTAL_TIME  nprocs  \
# 4050                0              0    -1         90.587130      96
# 4056                0              0    -1         96.198886      96
# 4060                0              0    -1         42.093948     256
# 4062                0              0    -1         38.330144     256
# 4067                0              0    -1         28.921739     256
# ...               ...            ...   ...               ...     ...
# 777396              0              0    -1        147.341001      16
# 777433              0              0    -1        249.543889       4
# 777507              0              0    -1        163.532403       4
# 777553              0              0     0        218.502730       4
# 777625              0              0     0        144.784950       4
#
#               exe  lustre                                               path
# 4050    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4056    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4060    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4062    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4067    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# ...           ...     ...                                                ...
# 777396  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 777433  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 777507  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 777553  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 777625  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
#
# [7052 rows x 93 columns]

# %%
test_dup_set = test_app[(test_app.POSIX_BYTES_READ == test_app_no_dups.iloc[2].POSIX_BYTES_READ)
         & (test_app.POSIX_BYTES_WRITTEN == test_app_no_dups.iloc[2].POSIX_BYTES_WRITTEN)]
test_dup_set
# Out:
#       POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 4060        13706            -17         -17       312320         32569
#
#       POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# 4060       255106        13706            0             0
#
#       POSIX_RENAME_SOURCES  ...  WRITE_4M_10M  WRITE_10M_100M  WRITE_100M_1G  \
# 4060                   -17  ...             0               0              0
#
#       WRITE_1G_PLUS  rank  POSIX_TOTAL_TIME  nprocs        exe  lustre  \
# 4060              0    -1         42.093948     256  vasp_gam        1
#
#                                                    path
# 4060  /hpcwork/noco0056/io_transfer_learning/data/bl...
#
# [1 rows x 93 columns]

# %% [markdown]
# Specify columns that may differ such that the corresponding rows are still considered as duplicate jobs:
# - POSIX_MAX_(READ/WRITE)\_Time_Size: which operation is the slowest/fastest might be affected by concurrent jobs running at the same time, possibly on the same node as well as IO weather.
# - POSIX_(FASTEST/SLOWEST)\_RANK: same as above.
# - POSIX_TOTAL_TIME: is the output feature
# - rank: duplicate jobs may have been scheduled to different nodes.

# %%
columns_dissimilar = ["POSIX_MAX_READ_TIME_SIZE", "POSIX_MAX_WRITE_TIME_SIZE", "POSIX_FASTEST_RANK", "POSIX_SLOWEST_RANK",
                      "rank","POSIX_TOTAL_TIME"]

# %%
test_app[test_app.duplicated(test_app.columns.difference(columns_dissimilar))]
# Out:
#         POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 4441           2314            -13         -13         4608            16
# 4455           3578            -17         -17        77120         26022
# 4518           3182            -20         -20        75713      58079393
# 4598           3182            -20         -20        75713      59738273
# 4649           3182            -20         -20        75713      58079393
# ...             ...            ...         ...          ...           ...
# 777677          882            -20         -20       147408      34572112
# 777680          822            -20         -20        91970      29500157
# 777681          818            -20         -20        94089      20325966
# 810837         3150            -20         -20        67648      12445960
# 810897         3150            -20         -20        67648      12445960
#
#         POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# 4441            194         2314            0             0
# 4455          64139         3578            0             0
# 4518          61515         3246            0             0
# 4598          61515         3246            0             0
# 4649          61515         3246            0             0
# ...             ...          ...          ...           ...
# 777677        16006          898            0             0
# 777680        15637          838            0             0
# 777681        15318          834            0             0
# 810837        60106         3214            0             0
# 810897        60106         3214            0             0
#
#         POSIX_RENAME_SOURCES  ...  WRITE_4M_10M  WRITE_10M_100M  \
# 4441                     -13  ...             0               0
# 4455                     -17  ...             0               0
# 4518                     -20  ...             0               0
# 4598                     -20  ...             0               0
# 4649                     -20  ...             0               0
# ...                      ...  ...           ...             ...
# 777677                   -20  ...             0               0
# 777680                   -20  ...             0               0
# 777681                   -20  ...             0               0
# 810837                   -20  ...             0               0
# 810897                   -20  ...             0               0
#
#         WRITE_100M_1G  WRITE_1G_PLUS  rank  POSIX_TOTAL_TIME  nprocs  \
# 4441                0              0    -1          2.733955     192
# 4455                0              0    -1         12.016318      64
# 4518                0              0    -1        296.457484      64
# 4598                0              0    -1        313.086068      64
# 4649                0              0    -1        298.274991      64
# ...               ...            ...   ...               ...     ...
# 777677              0              0    -1        256.205289      16
# 777680              0              0    -1        150.464894      16
# 777681              0              0    -1        158.052334      16
# 810837              0              0    -1         63.009715      64
# 810897              0              0    -1         63.310301      64
#
#               exe  lustre                                               path
# 4441    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4455    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4518    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4598    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 4649    vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# ...           ...     ...                                                ...
# 777677  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 777680  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 777681  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 810837  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 810897  vasp_gam        1  /hpcwork/noco0056/io_transfer_learning/data/bl...
#
# [41284 rows x 93 columns]

# %% [markdown]
# ### Now find duplicates for the entire dataset

# %%
df_no_time_dups = df_no_time[df_no_time.duplicated(df_no_time.columns.difference(columns_dissimilar))]
df_no_time_dups
# Out:
#         POSIX_OPENS  POSIX_FILENOS  POSIX_DUPS  POSIX_READS  POSIX_WRITES  \
# 106            2540          -2541       -2541         3499             0
# 143            1027          -1024       -1024           33            20
# 159            1922          -1923       -1923         2713             0
# 203            2234          -2235       -2235         3134             0
# 204            2522          -2523       -2523         3491             0
# ...             ...            ...         ...          ...           ...
# 820135        49152         -24576      -24576            0             0
# 820269            1             -7          -7            0             0
# 820333            1             -1          -1            0             0
# 820375        49152         -24576      -24576            0             0
# 820592        49152         -24576      -24576            0             0
#
#         POSIX_SEEKS  POSIX_STATS  POSIX_MMAPS  POSIX_FSYNCS  \
# 106               0         5081            0             0
# 143              14            3            0             0
# 159               0         3845            0             0
# 203               0         4469            0             0
# 204               0         5045            0             0
# ...             ...          ...          ...           ...
# 820135            0        24576            0             0
# 820269            0            6            0             0
# 820333            0            0            0             0
# 820375            0        24576            0             0
# 820592            0        24576            0             0
#
#         POSIX_RENAME_SOURCES  ...  WRITE_4M_10M  WRITE_10M_100M  \
# 106                    -2541  ...             0               0
# 143                    -1024  ...             0               0
# 159                    -1923  ...             0               0
# 203                    -2235  ...             0               0
# 204                    -2523  ...             0               0
# ...                      ...  ...           ...             ...
# 820135                -24576  ...             0               0
# 820269                    -7  ...             0               0
# 820333                    -1  ...             0               0
# 820375                -24576  ...             0               0
# 820592                -24576  ...             0               0
#
#         WRITE_100M_1G  WRITE_1G_PLUS  rank  POSIX_TOTAL_TIME  nprocs  \
# 106                 0              0     7          2.461696     423
# 143                 0              0     0          0.085740     768
# 159                 0              0   289          1.563848     320
# 203                 0              0    76          1.116228     372
# 204                 0              0   415          2.611028     420
# ...               ...            ...   ...               ...     ...
# 820135              0              0     4          0.907105      24
# 820269              0              0    -1          0.015424       1
# 820333              0              0    -1          0.015319       1
# 820375              0              0    21          0.891812      24
# 820592              0              0    18          0.768245      24
#
#                                                       exe  lustre  \
# 106                                             ./Hsigma        1
# 143                                            ./nek5000        1
# 159                                             ./Hsigma        1
# 203                                             ./Hsigma        1
# 204                                             ./Hsigma        1
# ...                                                   ...     ...
# 820135  /u/system/bwjenkins/mdtest-jenkins/mdtest/mdte...       0
# 820269  ApplyObservers -domaininput GrDomain.input -No...       1
# 820333  ApplyObservers -UseTimes 0 -domaininput OldHyD...       1
# 820375  /u/system/bwjenkins/mdtest-jenkins/mdtest/mdte...       0
# 820592  /u/system/bwjenkins/mdtest-jenkins/mdtest/mdte...       0
#
#                                                      path
# 106     /hpcwork/noco0056/io_transfer_learning/data/bl...
# 143     /hpcwork/noco0056/io_transfer_learning/data/bl...
# 159     /hpcwork/noco0056/io_transfer_learning/data/bl...
# 203     /hpcwork/noco0056/io_transfer_learning/data/bl...
# 204     /hpcwork/noco0056/io_transfer_learning/data/bl...
# ...                                                   ...
# 820135  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 820269  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 820333  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 820375  /hpcwork/noco0056/io_transfer_learning/data/bl...
# 820592  /hpcwork/noco0056/io_transfer_learning/data/bl...
#
# [175581 rows x 93 columns]

# %%
df_no_time_no_dups = df_no_time[df_no_time.duplicated(df_no_time.columns.difference(columns_dissimilar)) == False]

# %%
df_no_time_no_dups.to_csv(r"../data/blue_waters_posix_with_paths_no_negative_outliers_no_time_no_dups.csv",index=False)
